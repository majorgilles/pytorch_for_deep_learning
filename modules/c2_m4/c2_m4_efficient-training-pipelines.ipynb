# %% [markdown]
# # Course 2, Module 4 — Efficient Training Pipelines
#
# - [DeepLearning.AI platform](https://learn.deeplearning.ai/specializations/pytorch-for-deep-learning-professional-certificate/lesson)
# - [Module notes](README.md)
# - [GitHub issue #8](https://github.com/majorgilles/pytorch_for_deep_learning/issues/8)
#
# **Focus:** Profile input and training pipelines, then remove measured bottlenecks.
