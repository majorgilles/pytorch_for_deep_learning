# %% [markdown]
# # Course 3, Module 4 — Preparing Models for Deployment in PyTorch
#
# - [DeepLearning.AI platform](https://learn.deeplearning.ai/specializations/pytorch-for-deep-learning-professional-certificate/lesson)
# - [Module notes](README.md)
# - [GitHub issue #12](https://github.com/majorgilles/pytorch_for_deep_learning/issues/12)
#
# **Focus:** Export, track, prune, and quantize models with ONNX and MLflow workflows.
