# %% [markdown]
# # Course 2, Module 3 — Working with Text using Hugging Face
#
# - [DeepLearning.AI platform](https://learn.deeplearning.ai/specializations/pytorch-for-deep-learning-professional-certificate/lesson)
# - [Module notes](README.md)
# - [GitHub issue #7](https://github.com/majorgilles/pytorch_for_deep_learning/issues/7)
#
# **Focus:** Preprocess text and fine-tune PyTorch-based Hugging Face models.
