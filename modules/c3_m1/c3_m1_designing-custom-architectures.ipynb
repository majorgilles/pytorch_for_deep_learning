# %% [markdown]
# # Course 3, Module 1 — Designing Custom Architectures
#
# - [DeepLearning.AI platform](https://learn.deeplearning.ai/specializations/pytorch-for-deep-learning-professional-certificate/lesson)
# - [Module notes](README.md)
# - [GitHub issue #9](https://github.com/majorgilles/pytorch_for_deep_learning/issues/9)
#
# **Focus:** Build non-sequential architectures including Siamese networks, ResNet, and DenseNet.
