# %% [markdown]
# # Course 2, Module 2 — Working with Images using TorchVision
#
# - [DeepLearning.AI platform](https://learn.deeplearning.ai/specializations/pytorch-for-deep-learning-professional-certificate/lesson)
# - [Module notes](README.md)
# - [GitHub issue #6](https://github.com/majorgilles/pytorch_for_deep_learning/issues/6)
#
# **Focus:** Load, transform, augment, and classify image data with TorchVision models.
