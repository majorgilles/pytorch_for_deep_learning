# %% [markdown]
# # Course 3, Week 3 — Specialized Approaches to Natural Language Processing in PyTorch
#
# - [DeepLearning.AI platform](https://learn.deeplearning.ai/specializations/pytorch-for-deep-learning-professional-certificate/lesson)
# - [Week notes](README.md)
# - [GitHub issue #11](https://github.com/majorgilles/pytorch_for_deep_learning/issues/11)
#
# **Focus:** Build attention and Transformer components for language tasks.
