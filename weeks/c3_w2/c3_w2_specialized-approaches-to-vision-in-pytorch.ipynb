# %% [markdown]
# # Course 3, Week 2 — Specialized Approaches to Vision in PyTorch
#
# - [DeepLearning.AI platform](https://learn.deeplearning.ai/specializations/pytorch-for-deep-learning-professional-certificate/lesson)
# - [Week notes](README.md)
# - [GitHub issue #10](https://github.com/majorgilles/pytorch_for_deep_learning/issues/10)
#
# **Focus:** Interpret vision models and explore saliency, activation maps, and diffusion.
